# %%
import requests
count = 0
for i in range(20):
    url = "https://api.hh.ru/vacancies"
    params = {
        'text': 'программист python',
        'area': 1,
        'period': 30,
        'page': i,
        'per_page': 100,
        'only_with_salary': True
    }

    response = requests.get(url, params)
    response.raise_for_status()
    js = response.json()
    count += len(js['items'])
count
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[26], line 31
#      21 params = {
#      22     'text': f'программист {language}', #  программисты
#      23     'area': 1, #  из Москвы
#    (...)
#      27     #'only_with_salary': True
#      28 }
#      30 response = requests.get(url, params)
# ---> 31 response.raise_for_status()
#      32 tqdm.write(i)
#      33 js = response.json()
#
# File ~\.virtualenvs\language-salary\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.hh.ru/vacancies?text=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+JavaScript&area=1&period=30&page=0&per_page=100

# %%
js
# Out:
# {'errors': [{'value': 'captcha_required',
#    'captcha_url': 'https://hh.ru/account/captcha?state=pxvcxBozfu7ry7R4QCetFpRgByk-d8c77C_TwpAbKNKURyNV7jIN3ZmLkwVMlGAX9X92ALf-F3MD3TOXI4P-xaLLmF67NwQWLj5VXiPWIWSlUTYdE_Ghff29z-dC6i6-',
#    'type': 'captcha_required'}],
#  'request_id': '1687980190421fbf711c235f23c2216d'}

# %%
import requests

def predict_rub_salary_for_superjob(vacancy: dict):
    pass


token = "v3.r.137457653.7ea316e15b259c72cbb425cd3ad5a3eef3eb21a2.fbe8484fa854ad9fd2cc55f3776bd60959941488"

header = {"X-Api-App-Id": token}
url = "https://api.superjob.ru/2.0/vacancies/"

params = {
    'keyword': 'программист',
    'town': 'Москва'
}

response = requests.get(url, headers=header, params=params)

response.json()
# Out:
# {'objects': [{'canEdit': False,
#    'is_closed': False,
#    'id': 30755248,
#    'id_client': 329793,
#    'payment_from': 0,
#    'payment_to': 60000,
#    'date_pub_to': 1688826314,
#    'date_archived': 1686139202,
#    'date_published': 1688048714,
#    'address': 'Москва, улица Декабристов, 39',
#    'profession': 'Программист (системный администратор)',
#    'work': 'Аналитика и тестирование имеющихся программ, подбор необходимых. Программное сопровождение. Техническое сопровождение имеющейся компьютерной техники, оргтехники, подбор необходимой по характеристикам для учреждения. Разработка макетов информационных материалов для печати, сайта и электронных носителей, презентационных материалов. Техническое сопровождение компьютерных, телефонных сетей, серверного коммутационного оборудования.',
#    'compensation': 'Белая зарплата, соц. пакет. Обращаем внимание, что работа часто связана с разъездами, т. к. учреждения имеет 4 отдельно стоящих здания. Адреса: ул. Декабристов, 39; Полярная 24; Хачатуряна 3; Яблочкова 33.',
#    'candidat': 'Опыт работы в аналогичной должности от 3-х лет Высшее профессиональное (техническое или инженерно-экономическое) или среднее профессиональное (техническое или инженерно-экономическое) • Хорошее знание компьютерных сетей, протоколов и принципов работы. • Практические навыки администрирования операционных систем Windows и аналогичных, в т. ч. российского производства. • Уверенный пользователь Microsoft Office, программ: Photoshop, Corel, Power Point. Знание иных программ является конкурентным преимуществом при собеседовании. опыт установки Windows и других программ; уверенное знание аппаратной части ПК и номенклатуры современных комплектующих, принципов модернизации оборудования.',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<b>Обязанности:</b><br /><br />Аналитика и тестирование имеющихся программ, подбор необходимых. Программное сопровождение. Техническое сопровождение имеющейся компьютерной техники, оргтехники, подбор необходимой по характеристикам для учреждения. Разработка макетов информационных материалов для печати, сайта и электронных носителей, презентационных материалов. Техническое сопровождение компьютерных, телефонных сетей, серверного коммутационного оборудования.<br /><br /><b>Требования:</b><br /><br />Опыт работы в аналогичной должности от 3-х лет Высшее профессиональное (техническое или инженерно-экономическое) или среднее профессиональное (техническое или инженерно-экономическое) • Хорошее знание компьютерных сетей, протоколов и принципов работы. • Практические навыки администрирования операционных систем Windows и аналогичных, в т. ч. российского производства. • Уверенный пользователь Microsoft Office, программ: Photoshop, Corel, Power Point. Знание иных программ является конкурентным преимуществом при собеседовании. опыт установки Windows и других программ; уверенное знание аппаратной части ПК и номенклатуры современных комплектующих, принципов модернизации оборудования.<br /><br /><b>Условия:</b><br /><br />Белая зарплата, соц. пакет. Обращаем внимание, что работа часто связана с разъездами, т. к. учреждения имеет 4 отдельно стоящих здания. Адреса: ул. Декабристов, 39; Полярная 24; Хачатуряна 3; Яблочкова 33.',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 2, 'title': 'Высшее'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 329793,
#     'title': 'ГБУЗ Детская городская поликлиника №110',
#     'link': 'https://www.superjob.ru/clients/gbuz-detskaya-gorodskaya-poliklinika-110-329793/vacancies.html',
#     'industry': [],
#     'description': 'Лечебно-профилактическое учреждение, оказывающее медицинские услуги прикрепленному детскому населению по системе ОМС. В структуру учреждения входят: педиатрическое, дошкольно-школьное отделение, отделение специализированной помощи, травматологический пункт. 3 филиала.',
#     'vacancy_count': 26,
#     'staff_count': '500 — 1000',
#     'client_logo': None,
#     'address': None,
#     'addresses': [],
#     'url': 'http://www.dgp110.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1253039303,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48},
#       {'id': 55, 'title': 'Телекоммуникации и связь', 'key': 55},
#       {'id': 57, 'title': 'Техническая поддержка', 'key': 57},
#       {'id': 503, 'title': 'Внедрение и сопровождение ПО', 'key': 503}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (926) 17024XX',
#    'phones': [{'number': '792617024XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': None,
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'Детская городская поликлиника № 110',
#    'firm_activity': 'Лечебно-профилактическое учреждение, оказывающее медицинские услуги прикрепленному детскому населению по системе ОМС. В структуру учреждения входят: педиатрическое, дошкольно-школьное отделение, отделение специализированной помощи, травматологический пункт. имеет 3 филиала',
#    'link': 'https://www.superjob.ru/vakansii/programmist-30755248.html',
#    'latitude': 55.861076,
#    'longitude': 37.616711},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 46355782,
#    'id_client': 121161,
#    'payment_from': 0,
#    'payment_to': 0,
#    'date_pub_to': 1688997611,
#    'date_archived': 0,
#    'date_published': 1688047211,
#    'address': 'Московская область, Ленинский городской округ, Симферопольское шоссе, 25-й километр, с2',
#    'profession': 'Разработчик DWH (Oracle)',
#    'work': None,
#    'compensation': None,
#    'candidat': 'ГК МЕГАПОЛИС – группа компаний, владеющая и управляющая активами в сфере логистики и дистрибуции товаров повседневного спроса (FMCG): табачная и пивобезалкогольная продукция, бакалейные товары, зажигалки, элементы питания, контрацептивы, энергетики, OTP (сигары, сигариллы, табаки).\n \nВ настоящее время ГК МЕГАПОЛИС обладает крупнейшим портфелем контрактов, включая контракты на дистрибуцию в РФ:\n \n• табачной продукции с производителями Japan Tobacco International, Philip Morris International, Imperial Tobacco Group;\n \n• долгосрочный дистрибьюторский договор с производителем пивобезалкогольной продукции ОАО «Пивоваренная компания «Балтика» (Carlsberg Group);\n \n• дистрибьюторские контракты с производителями чая и кофе – Milagro Food и M.J.F. Teas (Dilmah);\n \n• дистрибьюторский контракт с производителем энергетических напитков Red Bull GmbH (Red Bull, Bullit).\n \nНа данный момент в ГК Мегаполис открыта вакансия "РАЗРАБОТЧИК ХРАНИЛИЩА ДАННЫХ"\n \nЗАДАЧИ ДЛЯ ВАС:\n \n• Разработка и анализ процедур загрузки данных в хранилище из систем источников (SAP, web-сервисы);\n \n• Развитие корпоративного хранилища данных на основе СУБД Oracle;\n \n• Разработка витрин данных;\n \n• Разработка ETL процессов и алгоритмов расчета;\n \n• Автоматизация отчетности и визуализация с использованием Oracle APEX;\n \n• Ведение документации по хранилищу и витринам данных.\n \nОТ ВАС МЫ ЖЕЛАЕМ ВИДЕТЬ:\n \n• Законченное высшее образование;\n \n• Знание архитектуры СУБД Oracle и опыт разработки под СУБД Oracle не менее 2-х лет;\n \n• Навыки разработки ETL процессов;\n \n• Знание SQL (PL/SQL) на высоком уровне, включая оптимизацию запросов;\n \n• Знание принципов построения хранилищ данных;\n \nВашим преимуществом будет:\n \n• Навыки разработки на Oracle APEX (знание CSS,HTML,JavaScript);\n \n• Опыт работы со средствами визуализации данных;\n \n• Наличие сертификатов Oracle;\n \n• Опыт работы с Arenadata/\n \nМЫ ПРЕДЛАГАЕМ:\n \n• Работу в крупнейшей (более 13000 чел), стабильной (25 лет на рынке), торговой компании с региональной сетью, ориентированной на долгосрочное сотрудничество.\n \n• Оформление по ТК РФ (ежегодный оплачиваемый отпуск, оплата листка временной нетрудоспособности, соблюдение прочих гарантий по ТК РФ).\n \n• Конкурентную белую заработную плату и реальную возможность профессионального развития в динамично растущем направлении.\n \n• Полис ДМС со стоматологией;\n \n• Корпоративную мобильную связь;\n \n• Частичную компенсацию обедов в корпоративном кафе в офисе;\n \n• Наставничество опытных коллег и возможности внутреннего и внешнего обучения;\n \n• Необходимую технику и софт для работы;\n \n• Доступ в корпоративную библиотеку Альпина;\n \n• Скидки от наших партнеров (фитнес, английский, театры и др.)\n \n• Удаленный формат работы, график 5/2',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p><p>ГК МЕГАПОЛИС – группа компаний, владеющая и управляющая активами в сфере логистики и дистрибуции товаров повседневного спроса (FMCG): табачная и пивобезалкогольная продукция, бакалейные товары, зажигалки, элементы питания, контрацептивы, энергетики, OTP (сигары, сигариллы, табаки).</p> <p>В настоящее время ГК МЕГАПОЛИС обладает крупнейшим портфелем контрактов, включая контракты на дистрибуцию в РФ:</p> <ul><li>табачной продукции с производителями Japan Tobacco International, Philip Morris International, Imperial Tobacco Group;</li> <li>долгосрочный дистрибьюторский договор с производителем пивобезалкогольной продукции ОАО «Пивоваренная компания «Балтика» (Carlsberg Group);</li> <li>дистрибьюторские контракты с производителями чая и кофе – Milagro Food и M.J.F. Teas (Dilmah);</li> <li>дистрибьюторский контракт с производителем энергетических напитков Red Bull GmbH (Red Bull, Bullit).</li> </ul><p>На данный момент в ГК Мегаполис открыта вакансия "РАЗРАБОТЧИК ХРАНИЛИЩА ДАННЫХ"</p> <p>ЗАДАЧИ ДЛЯ ВАС:</p> <ul><li>Разработка и анализ процедур загрузки данных в хранилище из систем источников (SAP, web-сервисы);</li> <li>Развитие корпоративного хранилища данных на основе СУБД Oracle;</li> <li>Разработка витрин данных;</li> <li>Разработка ETL процессов и алгоритмов расчета;</li> <li>Автоматизация отчетности и визуализация с использованием Oracle APEX;</li> <li>Ведение документации по хранилищу и витринам данных.</li> </ul><p>ОТ ВАС МЫ ЖЕЛАЕМ ВИДЕТЬ:</p> <ul><li>Законченное высшее образование;</li> <li>Знание архитектуры СУБД Oracle и опыт разработки под СУБД Oracle не менее 2-х лет;</li> <li>Навыки разработки ETL процессов;</li> <li>Знание SQL (PL/SQL) на высоком уровне, включая оптимизацию запросов;</li> <li>Знание принципов построения хранилищ данных;</li> </ul><p>Вашим преимуществом будет:</p> <ul><li>Навыки разработки на Oracle APEX (знание CSS,HTML,JavaScript);</li> <li>Опыт работы со средствами визуализации данных;</li> <li>Наличие сертификатов Oracle;</li> <li>Опыт работы с Arenadata/</li> </ul><p>МЫ ПРЕДЛАГАЕМ:</p> <ul><li>Работу в крупнейшей (более 13000 чел), стабильной (25 лет на рынке), торговой компании с региональной сетью, ориентированной на долгосрочное сотрудничество.</li> <li>Оформление по ТК РФ (ежегодный оплачиваемый отпуск, оплата листка временной нетрудоспособности, соблюдение прочих гарантий по ТК РФ).</li> <li>Конкурентную белую заработную плату и реальную возможность профессионального развития в динамично растущем направлении.</li> <li>Полис ДМС со стоматологией;</li> <li>Корпоративную мобильную связь;</li> <li>Частичную компенсацию обедов в корпоративном кафе в офисе;</li> <li>Наставничество опытных коллег и возможности внутреннего и внешнего обучения;</li> <li>Необходимую технику и софт для работы;</li> <li>Доступ в корпоративную библиотеку Альпина;</li> <li>Скидки от наших партнеров (фитнес, английский, театры и др.)</li> <li>Удаленный формат работы, график 5/2</li> </ul></p>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': False,
#    'agreement': True,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 2, 'title': 'Удалённая работа (на дому)'},
#    'education': {'id': 2, 'title': 'Высшее'},
#    'experience': {'id': 2, 'title': 'От 1 года'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 121161,
#     'title': 'МЕГАПОЛИС',
#     'link': 'https://www.superjob.ru/clients/megapolis-121161/vacancies.html',
#     'industry': [],
#     'description': 'ГК «МЕГАПОЛИС» – группа компаний, владеющая и управляющая активами в сфере логистики и дистрибуции товаров повседневного спроса (FMCG): табачная и пивобезалкогольная продукция, бакалейные товары, зажигалки, элементы питания, контрацептивы, энергетики, OTP (сигары, сигариллы, табаки).\n\nВ настоящее время ГК МЕГАПОЛИС обладает крупнейшим портфелем контрактов, включая контракты на дистрибуцию в РФ:\n• табачной продукции;\n• пивобезалкогольной продукции;\n• дистрибьюторские контракты с производителями чая и кофе;\n• дистрибьюторский контракт с производителем энергетических напитков Red Bull GmbH (Red Bull, Bullit)(ООО «Ред Булл (Рус)»).\n\nСтабильность и долголетняя история\n\nГК МЕГАПОЛИС начала свою де\xadятельность 20 лет назад. За это время мы построили ста\xadбильный, долго\xadсрочный и кли\xadенто\xadориентированный бизнес. И несмотря на наше лиди\xadрующее поло\xadжение на рынке, мы стре\xadмимся к бо́ль\xadшему, стоим планы и с опти\xadмизмом смотрим в будущее.\n\nШирокая география\n\nМы рабо\xadтаем по всей стране, с неве\xadроят\xadным по сво\xadей широ\xadте геогра\xadфическим покры\xadтием, со все\xadми кана\xadлами про\xadдаж; в сос\xadтав ГК МЕГА\xadПОЛИС вхо\xadдит крупней\xadший в России дистри\xadбутор ком\xadмерческого авто\xadтранспорта, собстве\xadнные ло\xadгисти\xadческие силы и активы, сильней\xadший игрок сег\xadмента элит\xadной табач\xadной продук\xadции. Мы яв\xadля\xadемся крупней\xadшей дистрибу\xadционной компа\xadнией в своем сегменте. Груп\xadпа компа\xadний МЕГА\xadПОЛИС – это 330 филиа\xadлов на всей терри\xadтории Рос\xadсии. Числен\xadность сотруд\xadников в Рос\xadсии сос\xadтав\xadляет более 15 000 чело\xadвек.\n\nВысокие позиции\n\nГруппа компаний МЕГА\xadПОЛИС зани\xadмает 6 место в рей\xadтинге Forbes - 200 круп\xadнейших частных ком\xadпаний России 2016. Мы зани\xadмаем 14 место в рей\xadтинге РБК – 500 лиде\xadров российс\xadкого биз\xadнеса 2015.\n\nЭтичный бизнес\n\nГК МЕГА\xadПОЛИС ве\xadдет свой биз\xadнес этич\xadным путем, это зна\xadчит, что комп\xadания неукос\xadнительно соб\xadлюдает законо\xadдательство и сле\xadдует луч\xadшим миро\xadвым прак\xadтиках веде\xadния биз\xadнеса. ГК МЕГА\xadПОЛИС всегда стре\xadмится осу\xadществлять дея\xadтельность в откры\xadтой и чест\xadной мане\xadре на основе взаим\xadной выгоды и добро\xadсовестного пред\xadприниматель\xadства, нетер\xadпимости к любым про\xadявлениям и ви\xadдам корруп\xadции, легал\xadизации дохо\xadдов, по\xadлучен\xadных преступ\xadным путем, не\xadзаконной торговли, руководствуясь высочайши\xadми стандар\xadтами добро\xadсовестности и закон\xadности.',
#     'vacancy_count': 414,
#     'staff_count': 'более 5000',
#     'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/121161_b2bc4d9152e8a2135351f3a727a88a13.png',
#     'address': 'Россия, Москва, Симферопольское шоссе, 3',
#     'addresses': [{'addressString': 'Россия, Москва, Симферопольское шоссе, 3',
#       'latitude': 55.569393,
#       'longitude': 37.602148,
#       'phones': [{'number': 74957455130, 'additionalNumber': None}]}],
#     'url': 'http://www.gkm.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1194504833,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (495) 74551XX',
#    'phones': [{'number': '749574551XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/121161_b2bc4d9152e8a2135351f3a727a88a13.png',
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'Мегаполис',
#    'firm_activity': 'ГК «МЕГАПОЛИС» – группа компаний, владеющая и управляющая активами в сфере логистики и дистрибуции товаров повседневного спроса (FMCG): табачная и пивобезалкогольная продукция, бакалейные товары, зажигалки, элементы питания, контрацептивы, энергетики, OTP (сигары, сигариллы, табаки).\n\nВ настоящее время ГК МЕГАПОЛИС обладает крупнейшим портфелем контрактов, включая контракты на дистрибуцию в РФ:\n• табачной продукции;\n• пивобезалкогольной продукции;\n• дистрибьюторские контракты с производителями чая и кофе;\n• дистрибьюторский контракт с производителем энергетических напитков Red Bull GmbH (Red Bull, Bullit)(ООО «Ред Булл (Рус)»).\n\nСтабильность и долголетняя история\n\nГК МЕГАПОЛИС начала свою деятельность 20 лет назад. За это время мы построили стабильный, долгосрочный и клиентоориентированный бизнес. И несмотря на наше лидирующее положение на рынке, мы стремимся к бо́льшему, стоим планы и с оптимизмом смотрим в будущее.\n\nШирокая география\n\nМы работаем по всей стране, с невероятным по своей широте географическим покрытием, со всеми каналами продаж; в состав ГК МЕГАПОЛИС входит крупнейший в России дистрибутор коммерческого автотранспорта, собственные логистические силы и активы, сильнейший игрок сегмента элитной табачной продукции. Мы являемся крупнейшей дистрибуционной компанией в своем сегменте. Группа компаний МЕГАПОЛИС – это 330 филиалов на всей территории России. Численность сотрудников в России составляет более 15 000 человек.\n\nВысокие позиции\n\nГруппа компаний МЕГАПОЛИС занимает 6 место в рейтинге Forbes - 200 крупнейших частных компаний России 2016. Мы занимаем 14 место в рейтинге РБК – 500 лидеров российского бизнеса 2015.\n\nЭтичный бизнес\n\nГК МЕГАПОЛИС ведет свой бизнес этичным путем, это значит, что компания неукоснительно соблюдает законодательство и следует лучшим мировым практиках ведения бизнеса. ГК МЕГАПОЛИС всегда стремится осуществлять деятельность в открытой и честной манере на основе взаимной выгоды и добросовестного предпринимательства, нетерпимости к любым проявлениям и видам коррупции, легализации доходов, полученных преступным путем, незаконной торговли, руководствуясь высочайшими стандартами добросовестности и законности.',
#    'link': 'https://www.superjob.ru/vakansii/razrabotchik-dwh-46355782.html',
#    'latitude': 55.535595,
#    'longitude': 37.609406},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 36805497,
#    'id_client': 951984,
#    'payment_from': 70000,
#    'payment_to': 80000,
#    'date_pub_to': 1688974809,
#    'date_archived': 1683709203,
#    'date_published': 1688024315,
#    'address': 'Москва, улица Академика Капицы, 11',
#    'profession': 'Инженер-программист',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Обязанности: Осуществляет внедрение и сопровождение программы КИС ЕМИАС, решает оперативные вопросы, связанные с внедрением данной программы, обеспечивает координацию работников организации по вопросам внедрения КИС ЕМИАС.\n• Выполняет работы по подготовке программ к отладке и проводит отладку\n• Разрабатывает инструкции по работе с программами, оформляет необходимую техническую документацию.\n• Определяет возможности использования готовых программных продуктов.\n• Осуществляет сопровождение внедренных программ и программных средств, разрабатывает и внедряет системы автоматической проверки правильности программ, типовые и стандартные программные средства, составляет технологию обработки информации\nТребования:\n• \n высшее образование;\n2) повышение квалификации;\n3) имеющее опыт практической работы в области разработки программного обеспечения не менее одного года.\nУсловия:\n• пятидневка с 9.00 до 17.30',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p><b><br /></b></p><b>Обязанности: </b>Осуществляет внедрение и сопровождение программы КИС ЕМИАС,   решает оперативные вопросы, связанные с внедрением  данной программы, обеспечивает координацию  работников организации по вопросам внедрения \nКИС ЕМИАС.<ul><li>Выполняет работы по подготовке программ к отладке и проводит отладку</li><li>Разрабатывает инструкции по работе с программами, оформляет необходимую техническую документацию.</li><li>Определяет возможности использования готовых программных продуктов.</li><li>Осуществляет сопровождение внедренных программ и программных средств, разрабатывает и внедряет системы автоматической проверки правильности программ, типовые и стандартные программные средства, составляет технологию обработки информации</li></ul><b>Требования:</b><ul><li><p> высшее образование;</p><p>2)  повышение квалификации;</p><p>3) имеющее опыт практической работы в\nобласти разработки программного обеспечения не менее одного года.</p></li></ul><b>Условия:</b><ul><li>пятидневка с 9.00 до 17.30</li></ul>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 2, 'title': 'Высшее'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 951984,
#     'title': 'Детский санаторий №15',
#     'link': 'https://www.superjob.ru/clients/detskij-sanatorij-15-951984/vacancies.html',
#     'industry': [],
#     'description': 'Медицинская реабилитация детей 4-10 лет с бронхолегочной патологией.',
#     'vacancy_count': 8,
#     'staff_count': '100 — 500',
#     'client_logo': None,
#     'address': None,
#     'addresses': [],
#     'url': None,
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1337351158,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 41, 'title': 'Инжиниринг', 'key': 41},
#       {'id': 48, 'title': 'Разработка, программирование', 'key': 48}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (495) 42978XX',
#    'phones': [{'number': '749542978XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': None,
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'Детский санаторий №15',
#    'firm_activity': 'Медицинская реабилитация детей 4-10 лет с бронхолегочной патологией.',
#    'link': 'https://www.superjob.ru/vakansii/inzhener-programmist-36805497.html',
#    'latitude': 55.62495,
#    'longitude': 37.524319},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 42446431,
#    'id_client': 2815788,
#    'payment_from': 150000,
#    'payment_to': 0,
#    'date_pub_to': 1688378104,
#    'date_archived': 0,
#    'date_published': 1688032504,
#    'address': None,
#    'profession': 'Разработчик PHP',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Botobot – один из самых успешных сервисов для интеграции мессенджеров и чат-ботов в продажи в России и СНГ. У нас более полутора миллионов пользователей и больше 45 тысяч магазинов. Мы расширяем функционал наших сервисов и ищем бекенд разработчика в команду. Вам предстоит заниматься интересными задачами по развитию нагруженной SaaS платформы. \n\nМы используем php 8.1, MySQL 8, Redis. Инфраструктура сервиса размещается в облаке AWS. Часть инфраструктуры оркестрируется через Kubernetes, другая часть в процессе переезда. В проекте мы используем EKS, RDS, ElastiCache, CloudWatch и тд. Над задачами работаем в Confluence, Jira, Gitlab.\n\nМы ожидаем, что Вы:\n• Имеете опыт разработки на PHP7.1+ более 2х лет\n• Работали с фреймворками Symfony, API-Platform, Yii2\n\n• Работали с реляционными базами данных\n• Умеете проектировать и реализовывать API\n• Имеете опыт работы с Docker\n\nУсловия:\n• Полностью удаленная работа\n\n• Гибкий рабочий график',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p><b>Botobot</b>\n – один из самых успешных сервисов для интеграции мессенджеров и \nчат-ботов в продажи в России и СНГ. У нас более полутора миллионов пользователей\n и больше 45 тысяч магазинов. Мы расширяем функционал наших сервисов и ищем бекенд разработчика в команду. Вам предстоит заниматься интересными задачами по развитию нагруженной SaaS платформы. <br /></p><p>Мы используем php 8.1, MySQL 8, Redis. Инфраструктура сервиса размещается в облаке AWS. Часть инфраструктуры оркестрируется через Kubernetes, другая часть в процессе переезда. В проекте мы используем EKS, RDS, ElastiCache, CloudWatch и тд. Над задачами работаем в Confluence, Jira, Gitlab.<br /></p><b><b>Мы ожидаем, что Вы:</b></b><ul><li>Имеете опыт разработки на PHP7.1+ более 2х лет</li><li>Работали с фреймворками Symfony, API-Platform, Yii2<br /></li><li>Работали с реляционными базами данных</li><li>Умеете проектировать и реализовывать API</li><li>Имеете опыт работы с Docker<br /></li></ul><b>Условия:</b><ul><li>Полностью удаленная работа<br /></li><li>Гибкий рабочий график<br /></li></ul>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 2, 'title': 'Удалённая работа (на дому)'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 2, 'title': 'От 1 года'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 2815788,
#     'title': 'Ботобот',
#     'link': 'https://www.superjob.ru/clients/botobot-2815788/vacancies.html',
#     'industry': [],
#     'description': 'Растущая e-commerce платформа для интеграции Telegram и мессенджеров в продажи, привлечения и удержания клиентов.',
#     'vacancy_count': 0,
#     'staff_count': 'менее 50',
#     'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/2815788_3f839a77243ef1396fed717fb0e806f8.png',
#     'address': None,
#     'addresses': [],
#     'url': 'https://www.botobot.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1457079332,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (915) 48170XX',
#    'phones': [{'number': '791548170XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/2815788_3f839a77243ef1396fed717fb0e806f8.png',
#    'highlight': True,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'Ботобот',
#    'firm_activity': 'Растущая e-commerce платформа для интеграции Telegram и мессенджеров в продажи, привлечения и удержания клиентов.',
#    'link': 'https://www.superjob.ru/vakansii/razrabotchik-php-42446431.html',
#    'latitude': None,
#    'longitude': None},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 45689506,
#    'id_client': 4366960,
#    'payment_from': 100000,
#    'payment_to': 0,
#    'date_pub_to': 1688742903,
#    'date_archived': 0,
#    'date_published': 1688050746,
#    'address': 'Москва, 6-я Радиальная улица, 9с1',
#    'profession': 'Инженер-программист',
#    'work': None,
#    'compensation': None,
#    'candidat': 'В производственную компанию приглашается Инженер-программист.\nОбязанности:\n• Разработка программного обеспечения для силовых преобразователей электроэнергии, вторичных источников питания, инверторов напряжения;\n• Участие в отладке изделий, в испытаниях на объекте эксплуатации – ж/д транспорте;\n• Ведение авторского контроля на производстве.\nТребования:\n\n• Образование в области радиоэлектроники.\n• Знание языков программирования С, С++.\n• Опыт работы с real-time микроконтроллерами (Texas Instruments C2000, STM32 или подобные) в области управления силовой электроникой.\n• Опыт работы с графическими средами разработки программ Visual C++, C-builder, Qt или подобными для создания сервисных программ.\n• Знание цифровой и аналоговой схемотехники, опыт практического применения.\n• Знание основ построения источников вторичного электропитания, силовой преобразовательной техники – приветствуется.\n• Знание основ теории автоматического управления и опыт моделирования в пакете программ MatLab или подобных.\n• Разработка ПО\nУсловия:\n• График работы с 9:00-18:00 ч. \n• Дружный коллектив\n• 7-10 минут от метро Царицыно.\n• Оплата переработки и сверхурочных строго по ТК.\n• Премия по результатам месяца, полугода, годовая премия.\n• Оплата командировочных и больничных\n• Оформление в штат в «белую»\n• Возможны разовые командировки.\n• Оформление ДМС (+Стоматология)',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p><b>В производственную компанию приглашается Инженер-программист.</b></p><b>Обязанности:</b><ul><li>Разработка программного обеспечения для силовых преобразователей электроэнергии, вторичных источников питания, инверторов напряжения;</li><li>Участие в отладке изделий, в испытаниях на объекте эксплуатации – ж/д транспорте;</li><li>Ведение авторского контроля на производстве.</li></ul>Требования:<br /><ul><li>Образование в области радиоэлектроники.</li><li>Знание языков программирования С, С++.</li><li>Опыт работы с real-time микроконтроллерами (Texas Instruments C2000, STM32 или подобные) в области управления силовой электроникой.</li><li>Опыт работы с графическими средами разработки программ Visual C++, C-builder, Qt или подобными для создания сервисных программ.</li><li>Знание цифровой и аналоговой схемотехники, опыт практического применения.</li><li>Знание основ построения источников вторичного электропитания, силовой преобразовательной техники – приветствуется.</li><li>Знание основ теории автоматического управления и опыт моделирования в пакете программ MatLab или подобных.</li><li>Разработка ПО</li></ul>Условия:<ul><li>График работы с 9:00-18:00 ч. </li><li>Дружный коллектив</li><li>7-10 минут от метро Царицыно.</li><li>Оплата переработки и сверхурочных строго по ТК.</li><li>Премия по результатам месяца, полугода, годовая премия.</li><li>Оплата командировочных и больничных</li><li>Оформление в штат в «белую»</li><li>Возможны разовые командировки.</li><li>Оформление ДМС (+Стоматология)</li></ul><p><br /></p>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 4366960,
#     'title': 'ЭЛЕКТРО СИ',
#     'link': 'https://www.superjob.ru/clients/elektro-si-4366960/vacancies.html',
#     'industry': [],
#     'description': 'Высокотехнологичное предприятие, разрабатывающее и выпускающее электронные преобразователи для их применения в различных отраслях промышленного и народного хозяйства. Диапазон выходной мощности преобразователей от десятков ватт до сотен киловатт.',
#     'vacancy_count': 0,
#     'staff_count': 'менее 50',
#     'client_logo': None,
#     'address': None,
#     'addresses': [],
#     'url': 'http://electro-si.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1659340798,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48}]},
#     {'id': 327,
#      'title': 'Промышленность, производство',
#      'key': 327,
#      'positions': [{'id': 332,
#        'title': 'Железнодорожное машиностроение',
#        'key': 332},
#       {'id': 342, 'title': 'Приборостроение', 'key': 342},
#       {'id': 346, 'title': 'Промышленное оборудование', 'key': 346},
#       {'id': 347,
#        'title': 'Радиотехническая и электронная промышленность',
#        'key': 347}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (495) 54421XX доб. 1114, +7 (903) 15793XX',
#    'phones': [{'number': '749554421XX', 'additionalNumber': 1114},
#     {'number': '790315793XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': None,
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'ЭЛЕКТРО СИ',
#    'firm_activity': 'Высокотехнологичное предприятие, разрабатывающее и выпускающее электронные преобразователи для их применения в различных отраслях промышленного и народного хозяйства. Диапазон выходной мощности преобразователей от десятков ватт до сотен киловатт.',
#    'link': 'https://www.superjob.ru/vakansii/inzhener-programmist-45689506.html',
#    'latitude': 55.605347,
#    'longitude': 37.649139},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 46314922,
#    'id_client': 665474,
#    'payment_from': 0,
#    'payment_to': 0,
#    'date_pub_to': 1688811923,
#    'date_archived': 0,
#    'date_published': 1688034101,
#    'address': 'Московская область, Щёлково, Заводская улица, 2к88',
#    'profession': 'Программист 1С',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Мы - международная компания по производству сэндвич-панелей и промышленных дверей, успешно работаем на рынке уже более 17-ти лет. Создаём инновационные технологии сохранения энергии и реализуем продукцию в 27 стран мира.\n\nРассматриваем кандидатов с минимальным опытом по специальности! Вакансия появилась в связи с расширением отдела.\nОбязанности:\n• Доработка и сопровождение 1С ERP, УПП\n• Тестирование разработанного программного продукта (в т.ч. написанного сторонним разработчиком)\n• Написание ТЗ и постановка задач разработчикам\n• Написание инструкций\n• Техническая поддержка пользователей\nТребования:\n• Опыт в программировании\n• Хорошее знание платформы "1С: Предприятие 8";\n• Владение СКД, написание сложных запросов;\n• Опыт разработки и поддержки приложений на платформе 1С\n• Создание технической документации;\nПриветствуется:\n• Опыт интеграции 1С (обмен данными) со сторонними системами\n• Опыт работы и интеграции ЭДО\nНаши условия:\n• Оформление по ТК РФ\n• График 5/2 с 9 до 18\n• Множество интересных задач и проектов\n• Коллектив профессионалов, у которых есть чему обучиться\n• Мы практикуем рост сотрудников внутри компании\n• Повышения квалификации за счёт компании',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p>Мы - международная компания по производству сэндвич-панелей и промышленных дверей, успешно работаем на рынке уже более 17-ти лет. Создаём инновационные технологии сохранения энергии и реализуем продукцию в 27 стран мира.</p><p><br />Рассматриваем кандидатов с минимальным опытом по специальности! Вакансия появилась в связи с расширением отдела.</p><p>Обязанности:</p><ul><li>Доработка и сопровождение 1С ERP, УПП</li><li>Тестирование разработанного программного продукта (в т.ч. написанного сторонним разработчиком)</li><li>Написание ТЗ и постановка задач разработчикам</li><li>Написание инструкций</li><li>Техническая поддержка пользователей</li></ul><p>Требования:</p><ul><li>Опыт в программировании</li><li>Хорошее знание платформы "1С: Предприятие 8";</li><li>Владение СКД, написание сложных запросов;</li><li>Опыт разработки и поддержки приложений на платформе 1С</li><li>Создание технической документации;</li></ul><p>Приветствуется:</p><ul><li>Опыт интеграции 1С (обмен данными) со сторонними системами</li><li>Опыт работы и интеграции ЭДО</li></ul><p>Наши условия:</p><ul><li>Оформление по ТК РФ</li><li>График 5/2 с 9 до 18</li><li>Множество интересных задач и проектов</li><li>Коллектив профессионалов, у которых есть чему обучиться</li><li>Мы практикуем рост сотрудников внутри компании</li><li>Повышения квалификации за счёт компании</li></ul>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': True,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 2, 'title': 'От 1 года'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 665474,
#     'title': 'ПрофХолод',
#     'link': 'https://www.superjob.ru/clients/profholod-665474/vacancies.html',
#     'industry': [],
#     'description': 'ПрофХолод» — инновационная компания, крупнейший в России производитель сэндвич-панелей с утеплителем из пенополиуретана.\n\n- 15 лет на российском рынке. Компанию знает любой, кто строил хотя бы одно овощехранилище или холодный склад\n- Производит более 3 млн квадратных метров сэндвич-панелей ежегодно на современном итальянском оборудовании\n- Каждый год отгружает продукцию более чем 2 тысячам клиентов со всего мира. Россия, США, Европа, Ближний Восток, СНГ\n- Сотрудничает с крупнейшими мировыми концернами Dow, BASF, Evonik и т. д. и развивает собственный научно-исследовательский комплекс\n- Посмотрите наше видео. И вы все поймете сами!\n«ПрофХолод» собирает лучший мировой опыт, приобретает лучшее зарубежное сырье и материалы и создает продукты для управления теплом. Зачем? Чтобы мир не тратил попусту энергию и деньги.\n\n«ПрофХолод» — это:\n\n- белая зарплата. Потому что мы работаем на будущее.\n- масштаб. Две тысячи клиентов со всего мира каждый год!\n- если вы менеджер по продажам, то ваш доход ограничен только вашими возможностями. российские и международные выставки. Много выставок в интересных городах и странах!\n- адаптация и обучение под руководством опытных коллег. Процесс интеграции включает погружение в технические детали, особенности b2b рынка и клиентов, детали производства. Все расскажем и покажем.\n- новые технологии, включая солнечную энергетику\n- производственная компания, которой можно гордиться\nМы готовы сделать все, чтобы мир осознал преимущества новых технологий и смог использовать их наилучшим образом.',
#     'vacancy_count': 15,
#     'staff_count': '100 — 500',
#     'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/665474_1dc93f31c6ded33711baf464ac26c926.jpg',
#     'address': None,
#     'addresses': [],
#     'url': 'http://www.profholod.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1305635226,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48},
#       {'id': 503, 'title': 'Внедрение и сопровождение ПО', 'key': 503}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (925) 64643XX',
#    'phones': [{'number': '792564643XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/665474_1dc93f31c6ded33711baf464ac26c926.jpg',
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'ПрофХолод',
#    'firm_activity': 'ПрофХолод» — инновационная компания, крупнейший в России производитель сэндвич-панелей с утеплителем из пенополиуретана. \n\n- 15 лет на российском рынке. Компанию знает любой, кто строил хотя бы одно овощехранилище или холодный склад\n- Производит более 3 млн квадратных метров сэндвич-панелей ежегодно на современном итальянском оборудовании\n- Каждый год отгружает продукцию более чем 2 тысячам клиентов со всего мира. Россия, США, Европа, Ближний Восток, СНГ\n- Сотрудничает с крупнейшими мировыми концернами Dow, BASF, Evonik и т. д. и развивает собственный научно-исследовательский комплекс\n- Посмотрите наше видео. И вы все поймете сами!\n«ПрофХолод» собирает лучший мировой опыт, приобретает лучшее зарубежное сырье и материалы и создает продукты для управления теплом. Зачем? Чтобы мир не тратил попусту энергию и деньги. \n\n«ПрофХолод» — это:\n\n- белая зарплата. Потому что мы работаем на будущее. \n- масштаб. Две тысячи клиентов со всего мира каждый год!\n- если вы менеджер по продажам, то ваш доход ограничен только вашими возможностями. российские и международные выставки. Много выставок в интересных городах и странах!\n- адаптация и обучение под руководством опытных коллег. Процесс интеграции включает погружение в технические детали, особенности b2b рынка и клиентов, детали производства. Все расскажем и покажем. \n- новые технологии, включая солнечную энергетику\n- производственная компания, которой можно гордиться\nМы готовы сделать все, чтобы мир осознал преимущества новых технологий и смог использовать их наилучшим образом.',
#    'link': 'https://www.superjob.ru/vakansii/programmist-1s-46314922.html',
#    'latitude': 55.913471,
#    'longitude': 38.036278},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 46376472,
#    'id_client': 3941774,
#    'payment_from': 250000,
#    'payment_to': 0,
#    'date_pub_to': 1690544169,
#    'date_archived': 1685345543,
#    'date_published': 1688038569,
#    'address': 'Москва, Серпуховско-Тимирязевская линия, метро Владыкино',
#    'profession': 'Программист 1С',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Обязанности:\n- Изучение и погружение в бизнес-процессы компании;\n- Разработка решений по внедрению бизнес-процессов в программу;\n- Планирование стадий внедрения в зависимости от потребностей бизнеса;\n- Выявление проблем, разработка решений, работа с 1 линией поддержки;\n- Ведение проектной документации;\n- Активное взаимодействие со сторонними сервисами, площадками в рамках внедрения сторонних продуктов.\n- Ведение задач, учет времени как своего так и команды.\n- Создание и поддержка спейсов, бордов и фильтров команды, обеспечение прозрачности процесса и результатов команды.\n- Организация тестирования продукта перед эксплуатацией.\n- Содержание продукта в бесперебойной среде функционирования\n- Доработка/разработка продукта на платформе 1С\n- Управление бэклогом;\n- Управление рисками;\nТребования:\n• \nЧто мы ждем от успешного кандидата на эту роль:\n- Играющий тренер;\n- Опыт управления проектами в сфере ИТ от 3 лет;\n- Хороший опыт в организации процесса разработки и написании соответствующих регламентов;\n- Опыт управления проектами по внедрению решений на базе 1С. Опыт участия в создании новых конфигураций/продуктов 1С;\n- Техническая грамотность и коммуникабельность;\n- Умение быстро переключаться в режиме многозадачности и принимать решения;\n- Знание и Умение работать с большими Базами данных.\n- Отличные организационные и аналитические навыки.\nУсловия:\n• \nЗаработная плата по результатам собеседования от 250000 руб\n• \nГрафик работы 5/2;\n• \nОформление по ТК РФ',
#    'metro': [],
#    'currency': 'rub',
#    'vacancyRichText': '<p>Обязанности:</p><p>- Изучение и погружение в бизнес-процессы компании;</p><p>- Разработка решений по внедрению бизнес-процессов в программу;</p><p>- Планирование стадий внедрения в зависимости от потребностей бизнеса;</p><p>- Выявление проблем, разработка решений, работа с 1 линией поддержки;</p><p>- Ведение проектной документации;</p><p>- Активное взаимодействие со сторонними сервисами, площадками в рамках внедрения сторонних продуктов.</p><p>- Ведение задач, учет времени как своего так и команды.</p><p>- Создание и поддержка спейсов, бордов и фильтров команды, обеспечение прозрачности процесса и результатов команды.</p><p>- Организация тестирования продукта перед эксплуатацией.</p><p>- Содержание продукта в бесперебойной среде функционирования</p><p>- Доработка/разработка продукта на платформе 1С</p><p>- Управление бэклогом;</p><p>- Управление рисками;</p><p>Требования:</p><ul><li><p>Что мы ждем от успешного кандидата на эту роль:</p><p>- Играющий тренер;</p><p>- Опыт управления проектами в сфере ИТ от 3 лет;</p><p>- Хороший опыт в организации процесса разработки и написании соответствующих регламентов;</p><p>- Опыт управления проектами по внедрению решений на базе 1С. Опыт участия в создании новых конфигураций/продуктов 1С;</p><p>- Техническая грамотность и коммуникабельность;</p><p>- Умение быстро переключаться в режиме многозадачности и принимать решения;</p><p>- Знание и Умение работать с большими Базами данных.</p>- Отличные организационные и аналитические навыки.</li></ul><p>Условия:</p><ul><li><p>Заработная плата по результатам собеседования от 250000  руб</p></li><li><p>График работы 5/2;</p></li><li><p>Оформление по ТК РФ</p></li></ul><p><br /></p>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
# ...
#    'metro': [{'id': 84, 'title': 'Марксистская', 'id_metro_line': 8},
#     {'id': 83, 'title': 'Площадь Ильича', 'id_metro_line': 8},
#     {'id': 152, 'title': 'Римская', 'id_metro_line': 10}],
#    'currency': 'rub',
#    'vacancyRichText': '<b>Обязанности:</b><ul><li><p>Разработка и поддержка большого\nembedded-linux приложения;   </p></li><li><p>работа с паттернами\nпроектирования - MVVM и DI;</p></li><li><p>работа c embedded linux\nсистемами;</p></li><li><p>работа на платформе .NET, WPF/AvaloniaUI, SQLite.</p></li></ul><p><b>Требования:</b></p><ul><li><p>Будет плюсом: знание и умение работать с .NET Reactive extensions.</p></li></ul><ul><li>опыт работа от 1 года.</li></ul><p><b>Условия:</b></p><p>Продолжительность рабочего времени 8 часов в день. Начало работы – 8:00 ч, окончание работы – 17:00 ч.</p><ul><li><ul><li>обеденный перерыв (продолжительностью 1 час);</li></ul><ul><li>выходные дни - суббота, воскресенье;</li><li>нерабочие праздничные дни;</li><li>ежегодный оплачиваемый отпуск (продолжительностью 28 календарных дней);</li><li>премии.</li></ul></li></ul>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 2, 'title': 'От 1 года'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 4466006,
#     'title': 'НПО СВЛ',
#     'link': 'https://www.superjob.ru/clients/npo-svl-4466006/vacancies.html',
#     'industry': [],
#     'description': 'Производство компьютеров и периферийного оборудования.',
#     'vacancy_count': 1,
#     'staff_count': 'менее 50',
#     'client_logo': None,
#     'address': None,
#     'addresses': [],
#     'url': 'https://nposvl.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1683098890,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48},
#       {'id': 49, 'title': 'Сетевые технологии', 'key': 49},
#       {'id': 51, 'title': 'Системное администрирование', 'key': 51}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (985) 42323XX',
#    'phones': [{'number': '798542323XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': None,
#    'highlight': False,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'НПО СВЛ',
#    'firm_activity': 'Производство компьютеров и периферийного оборудования.',
#    'link': 'https://www.superjob.ru/vakansii/programmist-46313842.html',
#    'latitude': 55.741871,
#    'longitude': 37.671841},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 46545559,
#    'id_client': 190447,
#    'payment_from': 0,
#    'payment_to': 0,
#    'date_pub_to': 1688802912,
#    'date_archived': 0,
#    'date_published': 1688025312,
#    'address': 'Москва, проспект Лихачева 15',
#    'profession': 'Разработчик 1С',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Обязанности:\n \n• Развитие и дальнейшая поддержка информационных систем на базе 1С;\n• Разработка и развитие эко-системы web-сервисов;\n• Активное участие в проектах интеграции информационных систем 1С между собой, а также с внутренними и внешними системами.\nУсловия:\n \n• Работу в аккредитованной ИТ-компании;\n• Реализация своего потенциала - интересные, амбициозные задачи;\n• Оформление согласно трудовому законодательству РФ;\n• Ежемесячные, квартальные премии;\n• Расширенный социальный пакет: ДМС (со стоматологией, услугами психолога), страхование жизни 24/7;\n• Компенсацию питания 4000 рублей до вычета налогов;\n• График работы 5/2;\n• Корпоративная мобильная связь;\n• Главный офис в шаговой доступности от МЦК ЗИЛ.\nТребования:\n \n• Опыт разработки на платформе 1С от 3-х лет;\n• Знание типового функционала УТ 11 и/или CRM (знание обеих конфигураций является преимуществом);\n• Опыт использования типового кода и приемов разработки, библиотеки стандартных подсистем, расширений конфигурации.\nНАМ ХОТЕЛОСЬ БЫ ВИДЕТЬ В ОПЫТЕ:\n• знание торговых и складских процессов;\n• опыт оптимизации нагруженных систем;\n• наличие сертификатов 1С:Специалист по платформе и других сертификатов.',
#    'metro': [{'id': 29, 'title': 'Автозаводская', 'id_metro_line': 2},
#     {'id': 593, 'title': 'ЗИЛ', 'id_metro_line': 44}],
#    'currency': 'rub',
#    'vacancyRichText': '<p><b>Обязанности:</b></p> <ul><li>Развитие и дальнейшая поддержка информационных систем на базе 1С;</li></ul><ul><li>Разработка и развитие эко-системы web-сервисов;</li><li>Активное участие в проектах интеграции информационных систем 1С между собой, а также с внутренними и внешними системами.</li></ul><p><b>Условия:</b></p> <ul><li>Работу в аккредитованной ИТ-компании;</li><li>Реализация своего потенциала - интересные, амбициозные задачи;</li><li>Оформление согласно трудовому законодательству РФ;</li><li>Ежемесячные, квартальные премии;</li><li>Расширенный социальный пакет: ДМС (со стоматологией, услугами психолога), страхование жизни 24/7;</li><li>Компенсацию питания 4000 рублей до вычета налогов;</li><li>График работы 5/2;</li><li>Корпоративная мобильная связь;</li><li>Главный офис в шаговой доступности от МЦК ЗИЛ.</li></ul><p><b>Требования:</b></p> <ul><li>Опыт разработки на платформе 1С от 3-х лет;</li><li>Знание типового функционала УТ 11 и/или CRM (знание обеих конфигураций является преимуществом);</li><li>Опыт использования типового кода и приемов разработки, библиотеки стандартных подсистем, расширений конфигурации.</li></ul><p>НАМ ХОТЕЛОСЬ БЫ ВИДЕТЬ В ОПЫТЕ:</p><ul><li>знание торговых и складских процессов;</li><li>опыт оптимизации нагруженных систем;</li><li>наличие сертификатов 1С:Специалист по платформе и других сертификатов.</li></ul></p>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': False,
#    'agreement': True,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 190447,
#     'title': 'Леруа Мерлен Восток',
#     'link': 'https://www.superjob.ru/clients/lerua-merlen-vostok-190447/vacancies.html',
#     'industry': [],
#     'description': 'Леруа Мерлен — французская компания-ритейлер, специализирующаяся на продаже товаров для строительства, отделки и обустройства дома, дачи и сада. Леруа Мерлен помогает людям во всем мире благоустроить жилье и улучшить качество жизни.\nСегодня в России ежедневно открывают свои двери для клиентов более 110 магазинов в 62 городах.\nБолее 35 000 сотрудников по всей стране работают в магазинах, на складах и центральном офисе.',
#     'vacancy_count': 666,
#     'staff_count': 'более 5000',
#     'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/190447_45abc6c3bd19b92987d015dadbf41ecd.png',
#     'address': None,
#     'addresses': [],
#     'url': 'http://rabota.leroymerlin.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1213702813,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (962) 98952XX',
#    'phones': [{'number': '796298952XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': 'https://public.superjob.ru/images/clients_logos.ru/190447_45abc6c3bd19b92987d015dadbf41ecd.png',
#    'highlight': True,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'Леруа Мерлен Восток',
#    'firm_activity': 'Леруа Мерлен — французская компания-ритейлер, специализирующаяся на продаже товаров для строительства, отделки и обустройства дома, дачи и сада. Леруа Мерлен помогает людям во всем мире благоустроить жилье и улучшить качество жизни.\nСегодня в России ежедневно открывают свои двери для клиентов более 110 магазинов в 62 городах.\nБолее 35 000 сотрудников по всей стране работают в магазинах, на складах и центральном офисе.',
#    'link': 'https://www.superjob.ru/vakansii/razrabotchik-1s-46545559.html',
#    'latitude': 55.699806,
#    'longitude': 37.644611},
#   {'canEdit': False,
#    'is_closed': False,
#    'id': 46707463,
#    'id_client': 728000,
#    'payment_from': 200000,
#    'payment_to': 0,
#    'date_pub_to': 1690444144,
#    'date_archived': 0,
#    'date_published': 1688024944,
#    'address': 'Москва, Малая Юшуньская улица, 1к1',
#    'profession': 'Ведущий программист 1С',
#    'work': None,
#    'compensation': None,
#    'candidat': 'Группа компаний Интерком- Мы являемся официальным федеральным дилером операторов сотовой связи: Теле 2, Мегафон, МТС, Билайн, XIAOMI.\nНаша розничная сеть насчитывает на сегодня более 100 салонов сотовой связи в Москве, МО и регионах, и более 250 работающих сотрудников.\nС 2018 года также активно развиваем сеть кофеен One price coffee.\nПриглашаем в свою команду ведущего программиста 1С\nОбязанности:\n• Оптимизация и автоматизация бизнес-процессов компании\n• Разработка новых и доработка текущих механизмов в системах (Розница 1, УПП 1.3, БУХ 3, ЗУП 3, самописные)\n• Разработка обменов с другими системами\nТребования:\n• Навыки написания интеграций и обменов через COM, HTTP-Сервисы, Web-Сервисы, REST API, РИБ, КД 2/3, EnterpriseData\n• Навыки написания оптимального кода, запросов\n• Навыки работы с СКД\n• Знание оперативного и бухгалтерского учетов\n• Умение читать и оптимизировать чужой код\n• Навыки работы с торговым оборудованием (ККТ, эквайринговые терминалы, проч.)\nУсловия:\n• График 5/2 с 09:00 до 18:00 (гибрид, после ИС возможна удаленка)\n• Оформление по ТК РФ;\n• Белая заработная плата;\n• Молодой и дружный коллектив;\n• Уютный офис рядом с м. Севастопольская',
#    'metro': [{'id': 26, 'title': 'Каховская', 'id_metro_line': 0},
#     {'id': 147, 'title': 'Севастопольская', 'id_metro_line': 9}],
#    'currency': 'rub',
#    'vacancyRichText': '<p>Группа компаний Интерком- Мы являемся официальным федеральным дилером операторов сотовой связи: Теле 2, Мегафон, МТС, Билайн, XIAOMI.</p><p>Наша розничная сеть насчитывает на сегодня более 100 салонов сотовой связи в Москве, МО и регионах, и более 250 работающих сотрудников.</p><p>С 2018 года также активно развиваем сеть кофеен One price coffee.</p><p>Приглашаем в свою команду ведущего программиста 1С</p><p>Обязанности:</p><ul><li>Оптимизация и автоматизация бизнес-процессов компании</li><li>Разработка новых и доработка текущих механизмов в системах (Розница 1, УПП 1.3, БУХ 3, ЗУП 3, самописные)</li><li>Разработка обменов с другими системами</li></ul><p>Требования:</p><ul><li>Навыки написания интеграций и обменов через COM, HTTP-Сервисы, Web-Сервисы, REST API, РИБ, КД 2/3, EnterpriseData</li><li>Навыки написания оптимального кода, запросов</li><li>Навыки работы с СКД</li><li>Знание оперативного и бухгалтерского учетов</li><li>Умение читать и оптимизировать чужой код</li><li>Навыки работы с торговым оборудованием (ККТ, эквайринговые терминалы, проч.)</li></ul><p>Условия:</p><ul><li>График 5/2 с 09:00 до 18:00 (гибрид, после ИС возможна удаленка)</li><li>Оформление по ТК РФ;</li><li>Белая заработная плата;</li><li>Молодой и дружный коллектив;</li><li>Уютный офис рядом с м. Севастопольская</li></ul>',
#    'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#    'moveable': True,
#    'agreement': False,
#    'anonymous': False,
#    'is_archive': False,
#    'is_storage': False,
#    'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#    'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#    'education': {'id': 0, 'title': 'Не имеет значения'},
#    'experience': {'id': 3, 'title': 'От 3 лет'},
#    'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#    'children': {'id': 0, 'title': 'Не имеет значения'},
#    'client': {'id': 728000,
#     'title': 'ГК ИНТЕРКОМ/ООО "ИНТЕРКОМ"',
#     'link': 'https://www.superjob.ru/clients/gk-interkom-ooo-interkom-728000/vacancies.html',
#     'industry': [],
#     'description': 'ГК "ИНТЕРКОМ" – устойчивая, динамично развивающаяся группа компаний, развивающаяся в области продажи услуг и оборудования мобильной связи с 1999 года. Одним из основных направлений деятельности ГК "Интерком" является розничная торговля мобильными телефонам',
#     'vacancy_count': 575,
#     'staff_count': '500 — 1000',
#     'client_logo': None,
#     'address': None,
#     'addresses': [],
#     'url': 'http://www.interc.ru',
#     'short_reg': False,
#     'is_blocked': False,
#     'registered_date': 1312456957,
#     'town': {'id': 4,
#      'title': 'Москва',
#      'declension': 'в Москве',
#      'hasMetro': True,
#      'genitive': 'Москвы'}},
#    'languages': [],
#    'driving_licence': [],
#    'catalogues': [{'id': 33,
#      'title': 'IT, Интернет, связь, телеком',
#      'key': 33,
#      'positions': [{'id': 48,
#        'title': 'Разработка, программирование',
#        'key': 48},
#       {'id': 53,
#        'title': 'Системы управления предприятием (ERP)',
#        'key': 53}]}],
#    'agency': {'id': 1, 'title': 'прямой работодатель'},
#    'town': {'id': 4,
#     'title': 'Москва',
#     'declension': 'в Москве',
#     'hasMetro': True,
#     'genitive': 'Москвы'},
#    'already_sent_on_vacancy': False,
#    'rejected': False,
#    'response_info': [],
#    'phone': '+7 (977) 97982XX',
#    'phones': [{'number': '797797982XX', 'additionalNumber': None}],
#    'fax': None,
#    'faxes': None,
#    'client_logo': None,
#    'highlight': True,
#    'age_from': 0,
#    'age_to': 0,
#    'gender': {'id': 0, 'title': 'Не имеет значения'},
#    'firm_name': 'ГК ИНТЕРКОМ/ООО "ИНТЕРКОМ"',
#    'firm_activity': 'ГК "ИНТЕРКОМ" – устойчивая, динамично развивающаяся группа компаний, развивающаяся в области продажи услуг и оборудования мобильной связи с 1999 года. Одним из основных направлений деятельности ГК "Интерком" является розничная торговля мобильными телефонам',
#    'link': 'https://www.superjob.ru/vakansii/veduschij-programmist-1s-46707463.html',
#    'latitude': 55.653221,
#    'longitude': 37.594513}],
#  'total': 96,
#  'more': True,
#  'subscription_id': 0,
#  'subscription_active': False}

# %%
k = response.json()['objects'][0]
k
# Out:
# {'canEdit': False,
#  'is_closed': False,
#  'id': 30755248,
#  'id_client': 329793,
#  'payment_from': 0,
#  'payment_to': 60000,
#  'date_pub_to': 1688826314,
#  'date_archived': 1686139202,
#  'date_published': 1688048714,
#  'address': 'Москва, улица Декабристов, 39',
#  'profession': 'Программист (системный администратор)',
#  'work': 'Аналитика и тестирование имеющихся программ, подбор необходимых. Программное сопровождение. Техническое сопровождение имеющейся компьютерной техники, оргтехники, подбор необходимой по характеристикам для учреждения. Разработка макетов информационных материалов для печати, сайта и электронных носителей, презентационных материалов. Техническое сопровождение компьютерных, телефонных сетей, серверного коммутационного оборудования.',
#  'compensation': 'Белая зарплата, соц. пакет. Обращаем внимание, что работа часто связана с разъездами, т. к. учреждения имеет 4 отдельно стоящих здания. Адреса: ул. Декабристов, 39; Полярная 24; Хачатуряна 3; Яблочкова 33.',
#  'candidat': 'Опыт работы в аналогичной должности от 3-х лет Высшее профессиональное (техническое или инженерно-экономическое) или среднее профессиональное (техническое или инженерно-экономическое) • Хорошее знание компьютерных сетей, протоколов и принципов работы. • Практические навыки администрирования операционных систем Windows и аналогичных, в т. ч. российского производства. • Уверенный пользователь Microsoft Office, программ: Photoshop, Corel, Power Point. Знание иных программ является конкурентным преимуществом при собеседовании. опыт установки Windows и других программ; уверенное знание аппаратной части ПК и номенклатуры современных комплектующих, принципов модернизации оборудования.',
#  'metro': [],
#  'currency': 'rub',
#  'vacancyRichText': '<b>Обязанности:</b><br /><br />Аналитика и тестирование имеющихся программ, подбор необходимых. Программное сопровождение. Техническое сопровождение имеющейся компьютерной техники, оргтехники, подбор необходимой по характеристикам для учреждения. Разработка макетов информационных материалов для печати, сайта и электронных носителей, презентационных материалов. Техническое сопровождение компьютерных, телефонных сетей, серверного коммутационного оборудования.<br /><br /><b>Требования:</b><br /><br />Опыт работы в аналогичной должности от 3-х лет Высшее профессиональное (техническое или инженерно-экономическое) или среднее профессиональное (техническое или инженерно-экономическое) • Хорошее знание компьютерных сетей, протоколов и принципов работы. • Практические навыки администрирования операционных систем Windows и аналогичных, в т. ч. российского производства. • Уверенный пользователь Microsoft Office, программ: Photoshop, Corel, Power Point. Знание иных программ является конкурентным преимуществом при собеседовании. опыт установки Windows и других программ; уверенное знание аппаратной части ПК и номенклатуры современных комплектующих, принципов модернизации оборудования.<br /><br /><b>Условия:</b><br /><br />Белая зарплата, соц. пакет. Обращаем внимание, что работа часто связана с разъездами, т. к. учреждения имеет 4 отдельно стоящих здания. Адреса: ул. Декабристов, 39; Полярная 24; Хачатуряна 3; Яблочкова 33.',
#  'covid_vaccination_requirement': {'id': 1, 'title': 'Не важно'},
#  'moveable': True,
#  'agreement': False,
#  'anonymous': False,
#  'is_archive': False,
#  'is_storage': False,
#  'type_of_work': {'id': 6, 'title': 'Полный рабочий день'},
#  'place_of_work': {'id': 0, 'title': 'Не имеет значения'},
#  'education': {'id': 2, 'title': 'Высшее'},
#  'experience': {'id': 3, 'title': 'От 3 лет'},
#  'maritalstatus': {'id': 0, 'title': 'Не имеет значения'},
#  'children': {'id': 0, 'title': 'Не имеет значения'},
#  'client': {'id': 329793,
#   'title': 'ГБУЗ Детская городская поликлиника №110',
#   'link': 'https://www.superjob.ru/clients/gbuz-detskaya-gorodskaya-poliklinika-110-329793/vacancies.html',
#   'industry': [],
#   'description': 'Лечебно-профилактическое учреждение, оказывающее медицинские услуги прикрепленному детскому населению по системе ОМС. В структуру учреждения входят: педиатрическое, дошкольно-школьное отделение, отделение специализированной помощи, травматологический пункт. 3 филиала.',
#   'vacancy_count': 26,
#   'staff_count': '500 — 1000',
#   'client_logo': None,
#   'address': None,
#   'addresses': [],
#   'url': 'http://www.dgp110.ru',
#   'short_reg': False,
#   'is_blocked': False,
#   'registered_date': 1253039303,
#   'town': {'id': 4,
#    'title': 'Москва',
#    'declension': 'в Москве',
#    'hasMetro': True,
#    'genitive': 'Москвы'}},
#  'languages': [],
#  'driving_licence': [],
#  'catalogues': [{'id': 33,
#    'title': 'IT, Интернет, связь, телеком',
#    'key': 33,
#    'positions': [{'id': 48,
#      'title': 'Разработка, программирование',
#      'key': 48},
#     {'id': 55, 'title': 'Телекоммуникации и связь', 'key': 55},
#     {'id': 57, 'title': 'Техническая поддержка', 'key': 57},
#     {'id': 503, 'title': 'Внедрение и сопровождение ПО', 'key': 503}]}],
#  'agency': {'id': 1, 'title': 'прямой работодатель'},
#  'town': {'id': 4,
#   'title': 'Москва',
#   'declension': 'в Москве',
#   'hasMetro': True,
#   'genitive': 'Москвы'},
#  'already_sent_on_vacancy': False,
#  'rejected': False,
#  'response_info': [],
#  'phone': '+7 (926) 17024XX',
#  'phones': [{'number': '792617024XX', 'additionalNumber': None}],
#  'fax': None,
#  'faxes': None,
#  'client_logo': None,
#  'highlight': False,
#  'age_from': 0,
#  'age_to': 0,
#  'gender': {'id': 0, 'title': 'Не имеет значения'},
#  'firm_name': 'Детская городская поликлиника № 110',
#  'firm_activity': 'Лечебно-профилактическое учреждение, оказывающее медицинские услуги прикрепленному детскому населению по системе ОМС. В структуру учреждения входят: педиатрическое, дошкольно-школьное отделение, отделение специализированной помощи, травматологический пункт. имеет 3 филиала',
#  'link': 'https://www.superjob.ru/vakansii/programmist-30755248.html',
#  'latitude': 55.861076,
#  'longitude': 37.616711}

# %%
bool(k['payment_from'])
# Out:
# False
