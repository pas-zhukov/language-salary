# %%
import requests
count = 0
for i in range(20):
    url = "https://api.hh.ru/vacancies"
    params = {
        'text': 'программист python',
        'area': 1,
        'period': 30,
        'page': i,
        'per_page': 100,
        'only_with_salary': True
    }

    response = requests.get(url, params)
    response.raise_for_status()
    js = response.json()
    count += len(js['items'])
count
# Out:
# 584

# %%
js
# Out:
# {'items': [{'id': '81697996',
#    'premium': False,
#    'name': 'Стажер-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 20000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T11:14:28+0300',
#    'created_at': '2023-06-26T11:14:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81697996',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81697996?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81697996',
#    'relations': [],
#    'employer': {'id': '5928535',
#     'name': 'Pacific.agency',
#     'url': 'https://api.hh.ru/employers/5928535',
#     'alternate_url': 'https://hh.ru/employer/5928535',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/4284528.png',
#      '240': 'https://hhcdn.ru/employer-logo/4284529.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/961003.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5928535',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Плюсом будет опыт работы с одним или несколькими языками программирования, такими как <highlighttext>Python</highlighttext>, JavaScript и т.д. (желательно иметь базовые...',
#     'responsibility': 'Помощь в разработке и поддержке программного кода в соответствии с требованиями проекта. Изучение языков программирования, фреймворков, библиотек и инструментов. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82464341',
#    'premium': False,
#    'name': 'Junior backend-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 90000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T17:30:31+0300',
#    'created_at': '2023-06-26T17:30:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82464341',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82464341?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82464341',
#    'relations': [],
#    'employer': {'id': '1911705',
#     'name': 'Хантфлоу',
#     'url': 'https://api.hh.ru/employers/1911705',
#     'alternate_url': 'https://hh.ru/employer/1911705',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/581223.png',
#      '240': 'https://hhcdn.ru/employer-logo/2766148.png',
#      '90': 'https://hhcdn.ru/employer-logo/2766147.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1911705',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Понимание нормализации, индексов, транзакций. Понимание концепции асинхронного i/o. Опыт оптимизации <highlighttext>python</highlighttext>-кода и SQL-запросов. Опыт работы с реляционными...',
#     'responsibility': 'Первые месяцы основная задача - миграции исторических данных новых клиентов в хантфлоу. Собеседование по Zoom с HR, которое включает общие вопросы. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82197901',
#    'premium': False,
#    'name': 'Стажер Web Программист в отдел разработки Интернет-Магазинов',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 30000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'lat': None,
#     'lng': None,
#     'description': None,
#     'raw': 'Москва, м. Профсоюзная',
#     'metro': None,
#     'metro_stations': [],
#     'id': '199464'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-20T17:36:01+0300',
#    'created_at': '2023-06-20T17:36:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82197901',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82197901?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82197901',
#    'relations': [],
#    'employer': {'id': '874852',
#     'name': 'АйТи-Матрикс',
#     'url': 'https://api.hh.ru/employers/874852',
#     'alternate_url': 'https://hh.ru/employer/874852',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3301044.png',
#      '240': 'https://hhcdn.ru/employer-logo/3301045.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/714982.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=874852',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'можете описать пример любой вашей разработки, хотя бы в рамках учебной программы. - знаете основы баз данных. - знаете основы HTML, JS...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#    'working_time_modes': [{'id': 'start_after_sixteen',
#      'name': 'Можно начинать работать после 16:00'}],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'part', 'name': 'Частичная занятость'}},
#   {'id': '82585620',
#    'premium': False,
#    'name': 'Junior Python - Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 70000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Бутлерова',
#     'building': '17',
#     'lat': 55.65015,
#     'lng': 37.539626,
#     'description': None,
#     'raw': 'Москва, улица Бутлерова, 17',
#     'metro': {'station_name': 'Калужская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.41',
#      'line_id': '6',
#      'lat': 55.656682,
#      'lng': 37.540075},
#     'metro_stations': [{'station_name': 'Калужская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.41',
#       'line_id': '6',
#       'lat': 55.656682,
#       'lng': 37.540075}],
#     'id': '11431915'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-27T19:35:29+0300',
#    'created_at': '2023-06-27T19:35:29+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82585620',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82585620?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82585620',
#    'relations': [],
#    'employer': {'id': '8890187',
#     'name': 'Коротких Никита Александрович',
#     'url': 'https://api.hh.ru/employers/8890187',
#     'alternate_url': 'https://hh.ru/employer/8890187',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/5484281.png',
#      '90': 'https://hhcdn.ru/employer-logo/5484280.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/966460.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=8890187',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Понимание того, что такое Ffmpeg. Умение писать Bash-команды. Представление того, что такое s3 и как туда загружать файл.',
#     'responsibility': 'Поддержка текущего кода генератора. Создание новых креативов по инструкции (Т/З).'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81549878',
#    'premium': False,
#    'name': 'Junior разработчик Python/Стажер',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-05T14:52:25+0300',
#    'created_at': '2023-06-05T14:52:25+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81549878',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81549878?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81549878',
#    'relations': [],
#    'employer': {'id': '5155838',
#     'name': 'Андреев Артём Александрович',
#     'url': 'https://api.hh.ru/employers/5155838',
#     'alternate_url': 'https://hh.ru/employer/5155838',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/905198.png',
#      '90': 'https://hhcdn.ru/employer-logo/4061479.png',
#      '240': 'https://hhcdn.ru/employer-logo/4061480.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5155838',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высокий уровень самоорганизованности и дисциплины. Наличие ПК, ноутбука, и высокоскоростного интернета. Обязателен опыт работы над коммерческим или опен-сорс проектом...',
#     'responsibility': 'Основное: решение тикетов, обращений от службы поддержки, написания тестов. Частично: поддержка существующего кода. Разработка новых фич.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'probation', 'name': 'Стажировка'}},
#   {'id': '82167814',
#    'premium': False,
#    'name': 'Разработчик Python (Junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 82500, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Хилков переулок',
#     'building': '1',
#     'lat': 55.736686,
#     'lng': 37.599328,
#     'description': None,
#     'raw': 'Москва, Хилков переулок, 1',
#     'metro': {'station_name': 'Парк культуры',
#      'line_name': 'Сокольническая',
#      'station_id': '1.103',
#      'line_id': '1',
#      'lat': 55.736163,
#      'lng': 37.595027},
#     'metro_stations': [{'station_name': 'Парк культуры',
#       'line_name': 'Сокольническая',
#       'station_id': '1.103',
#       'line_id': '1',
#       'lat': 55.736163,
#       'lng': 37.595027},
#      {'station_name': 'Парк культуры',
#       'line_name': 'Кольцевая',
#       'station_id': '5.104',
#       'line_id': '5',
#       'lat': 55.735221,
#       'lng': 37.593095}],
#     'id': '12980957'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-20T11:10:02+0300',
#    'created_at': '2023-06-20T11:10:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82167814',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82167814?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82167814',
#    'relations': [],
#    'employer': {'id': '2868315',
#     'name': 'КСЕНЬЕВСКИЙ ПРИИСК',
#     'url': 'https://api.hh.ru/employers/2868315',
#     'alternate_url': 'https://hh.ru/employer/2868315',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2151283.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2151282.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/427303.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2868315',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (также рассматриваются студенты старших курсов). Знание <highlighttext>Python</highlighttext>, SQL (MS-SQL, PostgreSQL). Понимание веб-технологий. Опыт Web Scraping. ',
#     'responsibility': 'Участие в проектах по автоматизации бизнес-процессов. Разработка парсеров сайтов для сбора и формализации данных. Поддержка существующих систем 1С...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82440187',
#    'premium': False,
#    'name': 'Data-инженер/Python-разработчик (strong junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T14:26:45+0300',
#    'created_at': '2023-06-26T14:26:45+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82440187',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82440187?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82440187',
#    'relations': [],
#    'employer': {'id': '9671220',
#     'name': 'Шонов Денис Олегович',
#     'url': 'https://api.hh.ru/employers/9671220',
#     'alternate_url': 'https://hh.ru/employer/9671220',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1072217.png',
#      '240': 'https://hhcdn.ru/employer-logo/5909498.png',
#      '90': 'https://hhcdn.ru/employer-logo/5909497.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9671220',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Знание языка <highlighttext>Python</highlighttext> на уровне strong junior. Опыт работы с базами данных. Опыт работы с Git. Умение работать в команде. ',
#     'responsibility': 'Разработка и поддержка программного обеспечения на языке <highlighttext>Python</highlighttext>. Работа с базами данных. Миграция движка по распознаванию данных.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82303507',
#    'premium': False,
#    'name': 'Front-end разработчик (React)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 80000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T16:05:00+0300',
#    'created_at': '2023-06-25T16:05:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82303507',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82303507?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82303507',
#    'relations': [],
#    'employer': {'id': '1202937',
#     'name': 'Akseler',
#     'url': 'https://api.hh.ru/employers/1202937',
#     'alternate_url': 'https://hh.ru/employer/1202937',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/396088.png',
#      '90': 'https://hhcdn.ru/employer-logo/2026606.png',
#      '240': 'https://hhcdn.ru/employer-logo/2026607.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1202937',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Минимум 6 месяцев опыта коммерческой разработки (опыт работы над реальным продуктом). Необходимо будет пройти техническое собеседование.',
#     'responsibility': 'Разработка на React, TypeScript, GrahpQL согласно поставленным задачам. Работа с Docker, Gitlab. Тестирование и документация кода. Отчетность Project-менеджеру (2...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81595610',
#    'premium': False,
#    'name': 'Junior Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-06T18:38:27+0300',
#    'created_at': '2023-06-06T18:38:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81595610',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81595610?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81595610',
#    'relations': [],
#    'employer': {'id': '4683890',
#     'name': 'Доценко Дарья',
#     'url': 'https://api.hh.ru/employers/4683890',
#     'alternate_url': 'https://hh.ru/employer/4683890',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4683890',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Интерес к теме. Внимательность, любопытство. Коммерческий опыт работы аналитиком не требуется.',
#     'responsibility': 'Аналитик будет разбираться в доменной области с помощью DS-навыков. Работа может включать анализ требований к компании со стороны торговых...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82466105',
#    'premium': False,
#    'name': 'Программист',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 90000, 'to': 90000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'посёлок завода Мосрентген',
#     'street': 'Институтский проезд',
#     'building': '2',
#     'lat': 55.610423,
#     'lng': 37.464706,
#     'description': None,
#     'raw': 'посёлок завода Мосрентген, Институтский проезд, 2',
#     'metro': {'station_name': 'Румянцево',
#      'line_name': 'Сокольническая',
#      'station_id': '1.513',
#      'line_id': '1',
#      'lat': 55.633,
#      'lng': 37.4419},
#     'metro_stations': [{'station_name': 'Румянцево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.513',
#       'line_id': '1',
#       'lat': 55.633,
#       'lng': 37.4419},
#      {'station_name': 'Саларьево',
#       'line_name': 'Сокольническая',
#       'station_id': '1.514',
#       'line_id': '1',
#       'lat': 55.6227,
#       'lng': 37.424},
#      {'station_name': 'Теплый Стан',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.140',
#       'line_id': '6',
#       'lat': 55.61873,
#       'lng': 37.505912}],
#     'id': '11437556'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T17:44:08+0300',
#    'created_at': '2023-06-26T17:44:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82466105',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82466105?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82466105',
#    'relations': [],
#    'employer': {'id': '2894216',
#     'name': 'НПП ВакЭТО',
#     'url': 'https://api.hh.ru/employers/2894216',
#     'alternate_url': 'https://hh.ru/employer/2894216',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2894216',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Способность разбираться в чужом коде и улучшать его характеристики. Владение языком программирования <highlighttext>Python</highlighttext>. Понимание принципов чистого кода и ведения документации. ',
#     'responsibility': 'Разработка интерфейса основной программы на С++. Обработка ошибок и тестирование конечного приложения (<highlighttext>Python</highlighttext>).'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81667130',
#    'premium': False,
#    'name': 'Junior Python Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Образцова',
#     'building': '38',
#     'lat': 55.791805,
#     'lng': 37.610107,
#     'description': None,
#     'raw': 'Москва, улица Образцова, 38',
#     'metro': {'station_name': 'Марьина Роща',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.185',
#      'line_id': '10',
#      'lat': 55.793723,
#      'lng': 37.61618},
#     'metro_stations': [{'station_name': 'Марьина Роща',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.185',
#       'line_id': '10',
#       'lat': 55.793723,
#       'lng': 37.61618}],
#     'id': '354800'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-07T15:48:11+0300',
#    'created_at': '2023-06-07T15:48:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81667130',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81667130?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81667130',
#    'relations': [],
#    'employer': {'id': '1469550',
#     'name': 'АО НТЦ Атлас',
#     'url': 'https://api.hh.ru/employers/1469550',
#     'alternate_url': 'https://hh.ru/employer/1469550',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/785649.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3583488.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3583487.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1469550',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': '<highlighttext>Python</highlighttext>, sqlalchemy. Nginx, postgesql / mysql, redis. Linux / macos. Git. Rest. Умение разбираться в чужом коде.',
#     'responsibility': 'Участие в разработке микросервисов и интернет порталов.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82030362',
#    'premium': False,
#    'name': 'Фронтенд разработчик на Javascript',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 150000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Крымский Вал',
#     'building': '3с2',
#     'lat': 55.729316,
#     'lng': 37.609173,
#     'description': None,
#     'raw': 'Москва, улица Крымский Вал, 3с2',
#     'metro': {'station_name': 'Октябрьская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.93',
#      'line_id': '5',
#      'lat': 55.729264,
#      'lng': 37.611049},
#     'metro_stations': [{'station_name': 'Октябрьская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.93',
#       'line_id': '5',
#       'lat': 55.729264,
#       'lng': 37.611049}],
#     'id': '12070914'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T12:18:08+0300',
#    'created_at': '2023-06-25T12:18:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82030362',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82030362?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82030362',
#    'relations': [],
#    'employer': {'id': '9312948',
#     'name': 'OPTIMAL CITY Technologies',
#     'url': 'https://api.hh.ru/employers/9312948',
#     'alternate_url': 'https://hh.ru/employer/9312948',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/6044730.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/6044729.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/1106031.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9312948',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': '...и других сборщиков, npm/yarn, typescript и т.п.). Опыт работы с Docker, Gitlab CI/CD. Базовые знания <highlighttext>Python</highlighttext> (backend).',
#     'responsibility': 'И детали.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81442417',
#    'premium': False,
#    'name': 'Python-разработчик (Junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 80000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-12T12:17:20+0300',
#    'created_at': '2023-06-12T12:17:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81442417',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81442417?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81442417',
#    'relations': [],
#    'employer': {'id': '4126352',
#     'name': 'Щербин Алексей Сергеевич',
#     'url': 'https://api.hh.ru/employers/4126352',
#     'alternate_url': 'https://hh.ru/employer/4126352',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4126352',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Профильное высшее образование. Знание языка <highlighttext>Python</highlighttext>. Опыт работы с PostgreSQL. Знание основ работы с Git и Docker. Знание английского языка...',
#     'responsibility': 'Разрабатывать алгоритмы торговых ботов и анализировать их эффективность. Работать с API различных криптовалютных бирж. Работать над оптимизацией скорости обработки данных...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81567192',
#    'premium': False,
#    'name': 'Младший аналитик (IT)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 140000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-05T20:11:21+0300',
#    'created_at': '2023-06-05T20:11:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81567192',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81567192?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81567192',
#    'relations': [],
#    'employer': {'id': '5686111',
#     'name': 'Olima',
#     'url': 'https://api.hh.ru/employers/5686111',
#     'alternate_url': 'https://hh.ru/employer/5686111',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/5626876.png',
#      '240': 'https://hhcdn.ru/employer-logo/5626877.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/1001524.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5686111',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в данной сфере необязателен. Перед трудоустройством проводится подготовка. Приветствуются базовые знания SQL, Java, <highlighttext>Python</highlighttext>, C#, JavaScript, PHP.',
#     'responsibility': 'Составление схем бизнес-процессов. Составление технических заданий (ТЗ). Постановка задач <highlighttext>разработчикам</highlighttext>. Контроль сроков выполнения задач. Расстановка приоритетов по задачам. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '10', 'name': 'Аналитик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81326476',
#    'premium': False,
#    'name': 'Разработчик Python (Junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T18:18:10+0300',
#    'created_at': '2023-06-26T18:18:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81326476',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81326476?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81326476',
#    'relations': [],
#    'employer': {'id': '5396549',
#     'name': 'EORA',
#     'url': 'https://api.hh.ru/employers/5396549',
#     'alternate_url': 'https://hh.ru/employer/5396549',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3821696.png',
#      '90': 'https://hhcdn.ru/employer-logo/3821695.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/845205.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5396549',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Обязательные: Умение писать хороший код на <highlighttext>Python</highlighttext> 3.9 и новее. Опыт в production-разработке, идеально если в заказной разработке. ',
#     'responsibility': 'Мы занимаемся автоматизацией коммуникаций: голосовые и текстовые чат-боты, IVR, обработка и анализ текстов с применением NLP. Работаем с классными...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82162078',
#    'premium': False,
#    'name': 'Разработчик Python / Django',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 150000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-20T10:12:16+0300',
#    'created_at': '2023-06-20T10:12:16+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82162078',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82162078?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82162078',
#    'relations': [],
#    'employer': {'id': '4767781',
#     'name': 'AlfaBit.Group',
#     'url': 'https://api.hh.ru/employers/4767781',
#     'alternate_url': 'https://hh.ru/employer/4767781',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/898562.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/4034935.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/4034936.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4767781',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Отличное знание <highlighttext>Python</highlighttext>, Django, Celery, PostgreSQL, Redis, ClickHouse (желателен опыт работы от 2-х лет). Опыт написания unit-тестов. ',
#     'responsibility': 'Участие в разработке проектов. Разработка backend (REST API ) для сервисов, как в рамках новых проектов, так и для уже существующих. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82371702',
#    'premium': False,
#    'name': 'Программист Python (разработка парсеров данных)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T22:12:35+0300',
#    'created_at': '2023-06-25T22:12:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82371702',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82371702?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82371702',
#    'relations': [],
#    'employer': {'id': '3241383',
#     'name': 'Пульс Продаж Новостроек',
#     'url': 'https://api.hh.ru/employers/3241383',
#     'alternate_url': 'https://hh.ru/employer/3241383',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/498052.png',
#      '90': 'https://hhcdn.ru/employer-logo/2433961.png',
#      '240': 'https://hhcdn.ru/employer-logo/2433962.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3241383',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы <highlighttext>программистом</highlighttext> <highlighttext>Python</highlighttext> от 1 года. Опыт работы с системами контроля версий. Базовые знания HTML, AJAX, HTTP, XML, JSON. ',
#     'responsibility': 'Исправление ошибок в наших парсерах. Разработка новых парсеров информации.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [{'id': 'only_saturday_and_sunday',
#      'name': 'Работа только по\xa0сб\xa0и\xa0вс'}],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#    'working_time_modes': [{'id': 'start_after_sixteen',
#      'name': 'Можно начинать работать после 16:00'}],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82339937',
#    'premium': False,
#    'name': 'Python-разработчик для создания портала по продаже автомобилей из Китая',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-23T13:50:56+0300',
#    'created_at': '2023-06-23T13:50:56+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82339937',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82339937?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82339937',
#    'relations': [],
#    'employer': {'id': '5066637',
#     'name': 'Уфимцева Ольга Сергеевна',
#     'url': 'https://api.hh.ru/employers/5066637',
#     'alternate_url': 'https://hh.ru/employer/5066637',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/5825254.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/5825253.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/1051150.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5066637',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с языком программирования <highlighttext>Python</highlighttext> и фреймворками, такими как Django или Flask. Знание основных принципов проектирования веб-приложений и...',
#     'responsibility': 'Разработка и поддержка веб-приложения на <highlighttext>Python</highlighttext> с использованием фреймворков, таких как Django или Flask. Проектирование и разработка базы данных...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82191978',
#    'premium': False,
#    'name': 'IT-специалист/Помощник разработчика',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 70000, 'to': 100000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Плеханова',
#     'building': '15Ас3',
#     'lat': 55.75014,
#     'lng': 37.765723,
#     'description': None,
#     'raw': 'Москва, улица Плеханова, 15Ас3',
#     'metro': {'station_name': 'Перово',
#      'line_name': 'Калининская',
#      'station_id': '8.107',
#      'line_id': '8',
#      'lat': 55.75098,
#      'lng': 37.78422},
#     'metro_stations': [{'station_name': 'Перово',
#       'line_name': 'Калининская',
#       'station_id': '8.107',
#       'line_id': '8',
#       'lat': 55.75098,
#       'lng': 37.78422},
#      {'station_name': 'Шоссе Энтузиастов',
#       'line_name': 'Калининская',
#       'station_id': '8.158',
#       'line_id': '8',
#       'lat': 55.75809,
#       'lng': 37.751703},
#      {'station_name': 'Шоссе Энтузиастов',
#       'line_name': 'МЦК',
#       'station_id': '95.524',
#       'line_id': '95',
#       'lat': 55.758633,
#       'lng': 37.748477}],
#     'id': '3557243'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T16:05:35+0300',
#    'created_at': '2023-06-26T16:05:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82191978',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82191978?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82191978',
#    'relations': [],
#    'employer': {'id': '3155981',
#     'name': 'Рамтроника',
#     'url': 'https://api.hh.ru/employers/3155981',
#     'alternate_url': 'https://hh.ru/employer/3155981',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3155981',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Знание языков программирования <highlighttext>Python</highlighttext>, Java Script. Опыт работы с инструментами Django, React. Будет плюсом знание SQL (в частности, PostgreSQL), и...',
#     'responsibility': 'Разработка корпоративной системы для автоматизации бизнес процессов компании.'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '78157311',
#    'premium': False,
#    'name': 'Chief Technology Officer/CTO',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 800000,
#     'to': 1200000,
#     'currency': 'RUR',
#     'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Пресненская набережная',
#     'building': '12',
#     'lat': 55.749511,
#     'lng': 37.537083,
#     'description': None,
#     'raw': 'Москва, Пресненская набережная, 12',
#     'metro': {'station_name': 'Выставочная',
#      'line_name': 'Филевская',
#      'station_id': '4.172',
#      'line_id': '4',
#      'lat': 55.750243,
#      'lng': 37.542641},
#     'metro_stations': [{'station_name': 'Выставочная',
#       'line_name': 'Филевская',
#       'station_id': '4.172',
#       'line_id': '4',
#       'lat': 55.750243,
#       'lng': 37.542641}],
#     'id': '2972225'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T20:14:50+0300',
#    'created_at': '2023-06-26T20:14:50+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=78157311',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/78157311?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/78157311',
#    'relations': [],
#    'employer': {'id': '4187159',
#     'name': 'HR СНАЙПЕР',
#     'url': 'https://api.hh.ru/employers/4187159',
#     'alternate_url': 'https://hh.ru/employer/4187159',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/5822566.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/5822565.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/1050478.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4187159',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Образование – высшее. Опыт работы в крупнейших мировых IT компаниях ( Google, Facebook, Microsoft, Amazon, Авито, Озон). Опыт работы в должности – более...',
#     'responsibility': 'Руководство подразделением (100 чел). Организация процессов от идеи до авторского надзора. Контроль сроков и качества выполненных работ. Организация, проведение совещаний. '},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '125', 'name': 'Технический директор (CTO)'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '81667285',
#    'premium': False,
#    'name': 'QA Engineer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Екатеринбург',
#     'street': 'проспект Ленина',
#     'building': '50Б',
#     'lat': 56.838804,
#     'lng': 60.623508,
#     'description': None,
#     'raw': 'Екатеринбург, проспект Ленина, 50Б',
#     'metro': {'station_name': 'Площадь 1905 года',
#      'line_name': 'Север-Юг',
#      'station_id': '48.266',
#      'line_id': '48',
#      'lat': 56.837982,
#      'lng': 60.59734},
#     'metro_stations': [{'station_name': 'Площадь 1905 года',
#       'line_name': 'Север-Юг',
#       'station_id': '48.266',
#       'line_id': '48',
#       'lat': 56.837982,
#       'lng': 60.59734}],
#     'id': '6892667'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-07T15:51:10+0300',
#    'created_at': '2023-06-07T15:51:10+0300',
# ...
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-я Владимирская улица',
#     'building': '62Б',
#     'lat': 55.739975,
#     'lng': 37.788261,
#     'description': None,
#     'raw': 'Москва, 2-я Владимирская улица, 62Б',
#     'metro': {'station_name': 'Перово',
#      'line_name': 'Калининская',
#      'station_id': '8.107',
#      'line_id': '8',
#      'lat': 55.75098,
#      'lng': 37.78422},
#     'metro_stations': [{'station_name': 'Перово',
#       'line_name': 'Калининская',
#       'station_id': '8.107',
#       'line_id': '8',
#       'lat': 55.75098,
#       'lng': 37.78422}],
#     'id': '1903082'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-14T13:05:21+0300',
#    'created_at': '2023-06-14T13:05:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=77806185',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/77806185?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/77806185',
#    'relations': [],
#    'employer': {'id': '973282',
#     'name': 'Аэроприбор-Восход',
#     'url': 'https://api.hh.ru/employers/973282',
#     'alternate_url': 'https://hh.ru/employer/973282',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/517838.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/2512830.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2512829.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=973282',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенные знания C/C++, Matlab, <highlighttext>Python</highlighttext> (numpy). Умение пользоваться системами контроля версий (Git). Английский язык (уровень не ниже B1). ',
#     'responsibility': 'Создание математических моделей на языках С++, Matlab, <highlighttext>Python</highlighttext>. Участие в отработке алгоритмов и консультации инженеров-<highlighttext>программистов</highlighttext> при реализации алгоритмов в...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '78577375',
#    'premium': False,
#    'name': 'Middle Back-end Developer (Node.js / JavaScript), удалённо',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Земляной Вал',
#     'building': '8',
#     'lat': 55.762151,
#     'lng': 37.656703,
#     'description': None,
#     'raw': 'Москва, улица Земляной Вал, 8',
#     'metro': None,
#     'metro_stations': [],
#     'id': '12670049'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-08T09:50:20+0300',
#    'created_at': '2023-06-08T09:50:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=78577375',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/78577375?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/78577375',
#    'relations': [],
#    'employer': {'id': '2440599',
#     'name': 'Поток.Диджитал',
#     'url': 'https://api.hh.ru/employers/2440599',
#     'alternate_url': 'https://hh.ru/employer/2440599',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/1040225.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/5781657.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/5781656.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2440599',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Желание развивать свои технические скиллы и реализовывать их на практике. Понимание микросервисной архитектуры, мониторинга, тестирования. Безопасности. Опыт работы с <highlighttext>python</highlighttext>...',
#     'responsibility': 'Разработка нового функционала согласно требованиям. Участие в проектировании функционала. Рефакторинг и оптимизация существующего кода. Проведение код-ревью. Участие в обсуждении...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82027615',
#    'premium': False,
#    'name': 'Инженер-робототехник (программист / АСУТП)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 120000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Рязанский проспект',
#     'building': '2с49',
#     'lat': 55.730441,
#     'lng': 37.736743,
#     'description': None,
#     'raw': 'Москва, Рязанский проспект, 2с49',
#     'metro': {'station_name': 'Нижегородская',
#      'line_name': 'Некрасовская',
#      'station_id': '98.765',
#      'line_id': '98',
#      'lat': 55.73,
#      'lng': 37.73},
#     'metro_stations': [{'station_name': 'Нижегородская',
#       'line_name': 'Некрасовская',
#       'station_id': '98.765',
#       'line_id': '98',
#       'lat': 55.73,
#       'lng': 37.73}],
#     'id': '6684078'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T11:49:38+0300',
#    'created_at': '2023-06-25T11:49:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82027615',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82027615?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82027615',
#    'relations': [],
#    'employer': {'id': '1337663',
#     'name': 'Top 3D Group',
#     'url': 'https://api.hh.ru/employers/1337663',
#     'alternate_url': 'https://hh.ru/employer/1337663',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/651061.png',
#      '90': 'https://hhcdn.ru/employer-logo/3045392.png',
#      '240': 'https://hhcdn.ru/employer-logo/3045393.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1337663',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': '...Gimatic, Schunk, SMC, OMRON, Camozzi и т.д. Знание языков программирования, таких как: C++\\C#\\Java\\<highlighttext>Python</highlighttext> на мидл уровне.',
#     'responsibility': 'Выбор основного и вспомогательного оборудования по проектам автоматизации производства. Разработка компоновки робототехнической ячейки, электрошкафов, компонентов оснастки роботов. Программирование промышленных и...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82280658',
#    'premium': False,
#    'name': 'Remote AI Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 1700, 'to': 7000, 'currency': 'EUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-25T11:05:10+0300',
#    'created_at': '2023-06-25T11:05:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82280658',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82280658?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82280658',
#    'relations': [],
#    'employer': {'id': '9230423',
#     'name': 'Rearden Media Ltd.',
#     'url': 'https://api.hh.ru/employers/9230423',
#     'alternate_url': 'https://hh.ru/employer/9230423',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9230423',
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': '2 years of machine learning engineering experience. 3 years of AI data science experience. At least 1 year of management...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'part', 'name': 'Частичная занятость'}},
#   {'id': '81235940',
#    'premium': False,
#    'name': 'Backend разработчик (Python) в IT компанию по разработке мобильных приложений',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-05-29T13:23:09+0300',
#    'created_at': '2023-05-29T13:23:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=81235940',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/81235940?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/81235940',
#    'relations': [],
#    'employer': {'id': '9068037',
#     'name': 'Development App Broseph',
#     'url': 'https://api.hh.ru/employers/9068037',
#     'alternate_url': 'https://hh.ru/employer/9068037',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/990717.png',
#      '90': 'https://hhcdn.ru/employer-logo/5583672.png',
#      '240': 'https://hhcdn.ru/employer-logo/5583673.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9068037',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Опыт разработки сложных проектов. - Обязателен опыт работы с django 2.*, <highlighttext>python</highlighttext> 3.7, djangorestframework. - Знание SQL (в частности, PostgreSQL) и...',
#     'responsibility': 'BACKEND <highlighttext>РАЗРАБОТЧИК</highlighttext> В IT КОМПАНИЮ ПО РАЗРАБОТКЕ МОБИЛЬНЫХ ПРИЛОЖЕНИЙ: Отрасль: Разработка IT проектов. - Создавать и тестировать API для мобильных приложений...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '82468499',
#    'premium': False,
#    'name': 'Fullstack developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 250000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-26T18:06:43+0300',
#    'created_at': '2023-06-26T18:06:43+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=82468499',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/82468499?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/82468499',
#    'relations': [],
#    'employer': {'id': '10002676',
#     'name': 'Xset Technologies',
#     'url': 'https://api.hh.ru/employers/10002676',
#     'alternate_url': 'https://hh.ru/employer/10002676',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10002676',
#     'accredited_it_employer': False,
#     'trusted': False},
#    'snippet': {'requirement': 'Опыт написания Java приложений от 2 лет. JS - react, angular. Умение проектирования и сборки бэкэнда приложений. Умение проектирования и сборки...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}},
#   {'id': '80747232',
#    'premium': False,
#    'name': 'Хемоинформатик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 190000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2023-06-18T20:01:25+0300',
#    'created_at': '2023-06-18T20:01:25+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=80747232',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/80747232?host=hh.ru',
#    'adv_response_url': None,
#    'alternate_url': 'https://hh.ru/vacancy/80747232',
#    'relations': [],
#    'employer': {'id': '4112759',
#     'name': 'Лаборатория Наносемантика',
#     'url': 'https://api.hh.ru/employers/4112759',
#     'alternate_url': 'https://hh.ru/employer/4112759',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/6020093.png',
#      '240': 'https://hhcdn.ru/employer-logo/6020094.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/1099870.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4112759',
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Хорошие навыки программирования на <highlighttext>Python</highlighttext>. Опыт работы с хемоинформатическими фреймворками и базами данных (например, RDKit, PubChem). Знание методов машинного обучения...',
#     'responsibility': 'Разработка и внедрение методов химинформатики для моделей ИИ для прогнозирования свойств малых молекул, извлечения данных из химической литературы, наполнения и...'},
#    'contacts': None,
#    'schedule': None,
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'}}],
#  'found': 582,
#  'pages': 6,
#  'per_page': 100,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&enable_snippets=true&items_on_page=100&only_with_salary=true&salary=10000&search_period=30&text=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+python'}
